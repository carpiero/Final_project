# %%
import pandas as pd

df_personal=pd.read_parquet(f'../data/processed/df_personal.parquet')
df_country=pd.read_parquet(f'../data/processed/df_country.parquet')
df_career=pd.read_parquet(f'../data/processed/df_career.parquet')
df_poll=pd.read_parquet(f'../data/processed/df_poll.parquet')

# %%
print(df_personal.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9649 entries, 0 to 9648
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uuid              9649 non-null   object
#  1   age               9649 non-null   int64
#  2   gender            9649 non-null   category
#  3   dem_has_children  9649 non-null   category
#  4   age_group         9649 non-null   category
# dtypes: category(3), int64(1), object(1)
# memory usage: 980.8 KB
# None

# %%
print(df_personal.nunique())
# Out:
# uuid                9649
# age                   52
# gender                 2
# dem_has_children       2
# age_group              3
# dtype: int64

# %%
print(df_country.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9649 entries, 0 to 9648
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uuid          9649 non-null   object
#  1   country_code  9649 non-null   category
#  2   rural         9649 non-null   category
# dtypes: category(2), object(1)
# memory usage: 898.4 KB
# None

# %%
print(df_country.nunique())
# Out:
# uuid            9649
# country_code      28
# rural              2
# dtype: int64

# %%
print(df_career.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9649 entries, 0 to 9648
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   uuid                 9649 non-null   object
#  1   dem_education_level  8986 non-null   object
#  2   dem_full_time_job    9649 non-null   category
#  3   normalized_job_code  5702 non-null   object
# dtypes: category(1), object(3)
# memory usage: 2.0 MB
# None

# %%
print(df_career.nunique())
# Out:
# uuid                   9649
# dem_education_level       4
# dem_full_time_job         2
# normalized_job_code     156
# dtype: int64

# %%
print(df_poll.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9649 entries, 0 to 9648
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uuid              9649 non-null   object
#  1   awareness         9649 non-null   category
#  2   vote              9649 non-null   category
#  3   effect            9649 non-null   category
#  4   argumentsfor      9649 non-null   object
#  5   argumentsagainst  9649 non-null   object
# dtypes: category(3), object(3)
# memory usage: 3.6 MB
# None

# %%
print(df_poll.nunique())
# Out:
# uuid                9649
# awareness              4
# vote                   5
# effect                 9
# argumentsfor         674
# argumentsagainst     881
# dtype: int64

# %%
from functools import reduce

dfs=[df_personal, df_country, df_career, df_poll]
df_final = reduce(lambda left,right: pd.merge(left,right,on='uuid'), dfs)

print(df_final.shape)
print(df_final.dtypes)
print(df_final.info(memory_usage='deep'))
print(df_final.nunique())
# Out:
# (9649, 15)
# uuid                     object
# age                       int64
# gender                 category
# dem_has_children       category
# age_group              category
# country_code           category
# rural                  category
# dem_education_level      object
# dem_full_time_job      category
# normalized_job_code      object
# awareness              category
# vote                   category
# effect                 category
# argumentsfor             object
# argumentsagainst         object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9649 entries, 0 to 9648
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   uuid                 9649 non-null   object
#  1   age                  9649 non-null   int64
#  2   gender               9649 non-null   category
#  3   dem_has_children     9649 non-null   category
#  4   age_group            9649 non-null   category
#  5   country_code         9649 non-null   category
#  6   rural                9649 non-null   category
#  7   dem_education_level  8986 non-null   object
#  8   dem_full_time_job    9649 non-null   category
#  9   normalized_job_code  5702 non-null   object
#  10  awareness            9649 non-null   category
#  11  vote                 9649 non-null   category
#  12  effect               9649 non-null   category
#  13  argumentsfor         9649 non-null   object
#  14  argumentsagainst     9649 non-null   object
# dtypes: category(9), int64(1), object(5)
# memory usage: 4.9 MB
# None
# uuid                   9649
# age                      52
# gender                    2
# dem_has_children          2
# age_group                 3
# country_code             28
# rural                     2
# dem_education_level       4
# dem_full_time_job         2
# normalized_job_code     156
# awareness                 4
# vote                      5
# effect                    9
# argumentsfor            674
# argumentsagainst        881
# dtype: int64

# %%
df_final
# Out:
#                                       uuid  age  gender dem_has_children  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82   61    Male               no
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82   57    Male              yes
# 2     83127080-da3d-0133-c74f-0a81e8b09a82   32    Male               no
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82   45    Male              yes
# 4     24954a70-db98-0133-4a64-0a81e8b09a82   41  Female              yes
# ...                                    ...  ...     ...              ...
# 9644  7d1ac020-dcb4-0133-817a-0a81e8b09a82   37  Female               no
# 9645  39f989f0-db52-0133-8482-0a81e8b09a82   53    Male              yes
# 9646  70ce4a90-d965-0133-f5e4-0a81e8b09a82   24    Male               no
# 9647  2896e440-db3c-0133-5b67-0a81e8b09a82   47    Male              yes
# 9648  06217ba0-dd56-0133-edda-0a81e8b09a82   51  Female              yes
#
#      age_group country_code  rural dem_education_level dem_full_time_job  \
# 0        40_65           AT  rural                  no                no
# 1        40_65           AT  urban                high               yes
# 2        26_39           AT  urban                None                no
# 3        40_65           AT  rural                high               yes
# 4        40_65           AT  urban                high               yes
# ...        ...          ...    ...                 ...               ...
# 9644     26_39           SK  urban                high               yes
# 9645     40_65           SK  urban                high               yes
# 9646     14_25           SK  urban                 low                no
# 9647     40_65           SK  urban                 low               yes
# 9648     40_65           SK  urban                high               yes
#
#                    normalized_job_code                            awareness  \
# 0                                 None            I know something about it
# 1     861a9b9151e11362eb3c77ca914172d0                I understand it fully
# 2                                 None  I have heard just a little about it
# 3     049a3f3a2b5f85cb2971ba77ad66e10c  I have heard just a little about it
# 4     f4b2fb1aa40f661488e2782b6d57ad2f  I have heard just a little about it
# ...                                ...                                  ...
# 9644  847165cfda6b1dc82ae22b967da8af2f                I understand it fully
# 9645  a4d5b8b38f9513825d0d94a981ebe962             I have never heard of it
# 9646                              None  I have heard just a little about it
# 9647  775190277a849cba701b306a7b374c0a                I understand it fully
# 9648  8a7a3f1bce0958ae9f090683e5a925b7                I understand it fully
#
#                                   vote  \
# 0                     I would not vote
# 1         I would probably vote for it
# 2                     I would not vote
# 3         I would probably vote for it
# 4         I would probably vote for it
# ...                                ...
# 9644      I would probably vote for it
# 9645  I would probably vote against it
# 9646                  I would not vote
# 9647               I would vote for it
# 9648           I would vote against it
#
#                                                effect  \
# 0                                   None of the above
# 1     A basic income would not affect my work choices
# 2                            I gain additional skills
# 3                                         I work less
# 4                                   None of the above
# ...                                               ...
# 9644                 I spend more time with my family
# 9645  A basic income would not affect my work choices
# 9646                 I spend more time with my family
# 9647  A basic income would not affect my work choices
# 9648  A basic income would not affect my work choices
#
#                                            argumentsfor  \
# 0                                     None of the above
# 1     It increases appreciation for household work a...
# 2               It creates more equality of opportunity
# 3        It reduces anxiety about financing basic needs
# 4        It reduces anxiety about financing basic needs
# ...                                                 ...
# 9644  It reduces bureaucracy and administrative expe...
# 9645  It reduces bureaucracy and administrative expe...
# 9646     It reduces anxiety about financing basic needs
# 9647  It reduces bureaucracy and administrative expe...
# 9648  It reduces bureaucracy and administrative expe...
#
#                                        argumentsagainst
# 0                                     None of the above
# 1             It might encourage people to stop working
# 2     Foreigners might come to my country and take a...
# 3                                     None of the above
# 4     It is impossible to finance | It might encoura...
# ...                                                 ...
# 9644                        It is impossible to finance
# 9645  It might encourage people to stop working | On...
# 9646                                  None of the above
# 9647  Foreigners might come to my country and take a...
# 9648  It might encourage people to stop working | It...
#
# [9649 rows x 15 columns]

# %%
df_final.to_parquet('../data/processed/df_final.parquet')
